# %% [markdown]
# ## NVIDIA GPUs Performace Comparison (value per price)
# Data source: https://en.wikipedia.org/wiki/List_of_Nvidia_graphics_processing_units#GeForce_30_series

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import dataframe_image as dfi

plt.rcParams["figure.dpi"] = 300
plt.rcParams["savefig.dpi"] = 300
plt.rcParams["figure.figsize"] = [12, 5]

df = pd.DataFrame()
df['name'] = ['GeForce RTX 4090', 'GeForce RTX 4080', 'GeForce RTX 4070 Ti', 'GeForce RTX 4070', 'GeForce RTX 3090 Ti', 'GeForce RTX 3090', 'GeForce RTX 3080 Ti', 'GeForce RTX 3080', 'GeForce RTX 3070 Ti', 'GeForce RTX 3070', 'GeForce RTX 3060 Ti', 'GeForce RTX 3060']
df['release_date'] = ['October 12, 2022', 'November 16, 2022', 'January 5, 2023', 'April 13, 2023', 'March 29, 2022', 'September 24, 2020', 'June 3, 2021', 'January 27, 2022', 'June 10, 2021', 'October 29, 2020', 'October 27, 2022', 'September 1, 2021']
df['price'] = [2007.58, 1441.61, 1226.36, 875.47, 1368.88, 1328.24, 1177.12, 900.77, 910.68, 591.89, 610.55, 511.45]
df['tdp_watts'] = [450, 320, 285, 200, 450, 350, 350, 350, 290, 220, 200, 170]
df['ray_traycing_tflops'] = [191, 112.7, 92.7, None, 79.9, 71.1, 68.2, 61.3, 43.5, 40.6, 32.4, 25]
df['tensor_compute_tflops'] = [292, 172, 142, None, 269.1, 235.08, 228.6, 180.6, 154.8, 141.31, 109.7, 75.7]
df['half_precision_tflops'] = [73.1, 43.0, 35.5, 22.6, 33.5, 29.38, 28.06, 22.6, 19.35, 17.66, 13.70, 9.46]
df['double_precision_tflops'] = [1.142, 0.672, 0.554, 0.353, 0.524, 0.459, 0.438, 0.353, 0.302, 0.276, 0.214, 0.148]
df['single_precision_tflops'] = [73.1, 43.0, 35.5, 22.6, 33.5, 29.28, 28.57, 22.6, 19.35, 17.66, 13.72, 9.46]
df['fillrate_gts'] = [1290.2, 761.5, 626.4, 455.4, 524.2, 457.6, 438.5, 352.8, 302.36, 276.0, 214.3, 147.8]
df['fillrate_gps'] = [443.5, 280.6, 208.8, 158.4, 174.7, 156.2, 153.5, 131.0, 151.18, 144.0, 112.8, 63.4]
df['clock_speed_mhz'] = [2230, 2210, 2310, 1920, 1560, 1395, 1365, 1260, 1575, 1500, 1410, 1320]

for column in df.columns[3:]:
    df[column] = df['price'] / df[column]
    
df['tdp_watts'] = df['tdp_watts'] * -1
df = df.sort_values(by=['release_date'], ascending=True)
df['mean'] = df[df.columns[3:]].mean(axis=1)

def pretty_panda(x):
    return (df.style
                .background_gradient()
                .set_properties(**{'font-size': '10pt'})
                .format(precision=2)
                .set_caption("NVIDIA GPUs Performace Comparison (value per 1$)")
                .set_table_styles([
                    {'selector': 'thead', 'props': 'text-transform: uppercase;'},
                    {'selector': 'caption', 'props': 'font-size: 20px'}
                ]))

df = pretty_panda(df)
df
# Out:
# <style type="text/css">
# #T_e4ea8 thead {
#   text-transform: uppercase;
# }
# #T_e4ea8 caption {
#   font-size: 20px;
# }
# #T_e4ea8_row0_col0, #T_e4ea8_row0_col1, #T_e4ea8_row1_col0, #T_e4ea8_row1_col1, #T_e4ea8_row2_col0, #T_e4ea8_row2_col1, #T_e4ea8_row3_col0, #T_e4ea8_row3_col1, #T_e4ea8_row4_col0, #T_e4ea8_row4_col1, #T_e4ea8_row5_col0, #T_e4ea8_row5_col1, #T_e4ea8_row6_col0, #T_e4ea8_row6_col1, #T_e4ea8_row7_col0, #T_e4ea8_row7_col1, #T_e4ea8_row8_col0, #T_e4ea8_row8_col1, #T_e4ea8_row9_col0, #T_e4ea8_row9_col1, #T_e4ea8_row10_col0, #T_e4ea8_row10_col1, #T_e4ea8_row11_col0, #T_e4ea8_row11_col1 {
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col3, #T_e4ea8_row8_col2 {
#   background-color: #f5eff6;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col4, #T_e4ea8_row0_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col6, #T_e4ea8_row0_col7, #T_e4ea8_row0_col8 {
#   background-color: #93b5d6;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col9 {
#   background-color: #dddbec;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col10 {
#   background-color: #b8c6e0;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col11 {
#   background-color: #ede7f2;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row0_col12 {
#   background-color: #04629a;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col2, #T_e4ea8_row2_col4 {
#   background-color: #cdd0e5;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col3, #T_e4ea8_row2_col5, #T_e4ea8_row3_col4, #T_e4ea8_row7_col2, #T_e4ea8_row10_col6, #T_e4ea8_row10_col7, #T_e4ea8_row10_col8, #T_e4ea8_row10_col9, #T_e4ea8_row10_col12, #T_e4ea8_row11_col10, #T_e4ea8_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col4, #T_e4ea8_row2_col10 {
#   background-color: #9cb9d9;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col5, #T_e4ea8_row6_col9 {
#   background-color: #e0deed;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col6, #T_e4ea8_row1_col7, #T_e4ea8_row1_col8, #T_e4ea8_row1_col12 {
#   background-color: #81aed2;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col9 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col10 {
#   background-color: #348ebf;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row1_col11 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row2_col2 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row2_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row2_col6, #T_e4ea8_row2_col7, #T_e4ea8_row2_col8, #T_e4ea8_row2_col12, #T_e4ea8_row3_col2 {
#   background-color: #cacee5;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row2_col9 {
#   background-color: #d9d8ea;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row2_col11 {
#   background-color: #ced0e6;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col3 {
#   background-color: #167bb6;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col5 {
#   background-color: #a4bcda;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col6, #T_e4ea8_row3_col8 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col7, #T_e4ea8_row3_col12 {
#   background-color: #0872b1;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col9 {
#   background-color: #056dac;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col10 {
#   background-color: #8eb3d5;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row3_col11 {
#   background-color: #b3c3de;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col3, #T_e4ea8_row4_col9 {
#   background-color: #4697c4;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col4, #T_e4ea8_row8_col7, #T_e4ea8_row8_col12 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col5 {
#   background-color: #d8d7e9;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col6, #T_e4ea8_row11_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col7, #T_e4ea8_row4_col12 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col8 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col10 {
#   background-color: #05659f;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row4_col11 {
#   background-color: #046096;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col2 {
#   background-color: #509ac6;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col3 {
#   background-color: #056fae;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col4 {
#   background-color: #328dbf;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col5 {
#   background-color: #dbdaeb;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col6, #T_e4ea8_row5_col7, #T_e4ea8_row5_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col9 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col10 {
#   background-color: #045e94;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col11 {
#   background-color: #045b8e;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row5_col12 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col3, #T_e4ea8_row7_col4, #T_e4ea8_row7_col6, #T_e4ea8_row7_col7, #T_e4ea8_row7_col8, #T_e4ea8_row7_col9, #T_e4ea8_row7_col12, #T_e4ea8_row9_col5, #T_e4ea8_row9_col10, #T_e4ea8_row10_col2, #T_e4ea8_row10_col11 {
#   background-color: #fff7fb;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col5 {
#   background-color: #03476f;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col6, #T_e4ea8_row6_col7, #T_e4ea8_row6_col8, #T_e4ea8_row6_col12, #T_e4ea8_row9_col6, #T_e4ea8_row9_col7, #T_e4ea8_row9_col8, #T_e4ea8_row9_col12 {
#   background-color: #d5d5e8;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col10 {
#   background-color: #d4d4e8;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row6_col11 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row7_col3 {
#   background-color: #fcf4fa;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row7_col5 {
#   background-color: #4094c3;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row7_col10 {
#   background-color: #f1ebf4;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row7_col11 {
#   background-color: #03517e;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col3 {
#   background-color: #056faf;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col4 {
#   background-color: #0567a2;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col5, #T_e4ea8_row9_col9 {
#   background-color: #bcc7e1;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col6 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col8 {
#   background-color: #308cbe;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col9 {
#   background-color: #2182b9;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col10 {
#   background-color: #c1cae2;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row8_col11 {
#   background-color: #f3edf5;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row9_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row9_col3 {
#   background-color: #034871;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row9_col4 {
#   background-color: #a1bbda;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row9_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
#   font-size: 10pt;
# }
# #T_e4ea8_row10_col3 {
#   background-color: #056ba9;
#   color: #f1f1f1;
#   font-size: 10pt;
# }
# #T_e4ea8_row10_col4 {
#   background-color: #03446a;
#   color: #f1f1f1;
#   font-size: 10pt;

# %%
# save dataframe as png
dfi.export(df.set_properties(**{'font-size': '16pt'}), "gpus_comparison.png", dpi=150)

# %% [markdown]
# ![alt](gpus_comparison.png)
