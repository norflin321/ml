# %% [markdown]
# <a href="https://colab.research.google.com/github/norflin321/ml/blob/main/txt2audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U protobuf
# !pip install -U diffusers
# !pip install -U transformers
# !pip install -U torchsde

import torch
import soundfile as sf
from diffusers import StableAudioPipeline

pipe = StableAudioPipeline.from_pretrained("stabilityai/stable-audio-open-1.0", torch_dtype=torch.float16, token="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")
pipe = pipe.to("cuda")
# Out:
# ...
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# diffusion_pytorch_model.safetensors:  10%|#         | 430M/4.23G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:  69%|######8   | 430M/624M [00:00<?, ?B/s]
# model.safetensors:  10%|9         | 463M/4.85G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8bf834b54603> in <cell line: 13>()
#      11 login()
#      12
# ---> 13 pipe = StableAudioPipeline.from_pretrained("stabilityai/stable-audio-open-1.0", torch_dtype=torch.float16, token="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")
#      14 pipe = pipe.to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
# ...

# %%
negative_prompt = "Low quality."

prompt = "Generate a sound effect that represents an item being removed from a bag in a mobile game. The sound should have a soft 'whoosh' or 'pop' to indicate movement, followed by a light, satisfying rustle or fabric-like sound to resemble the opening of a bag. The tone should be bright and uplifting, conveying a sense of accomplishment, but subtle enough to avoid being distracting. Ensure the sound is brief (around 1 second) and has a polished, digital quality suitable for casual games."

audio = pipe(
    prompt,
    negative_prompt=negative_prompt,
    num_inference_steps=100,
    audio_end_in_s=1.0,
    num_waveforms_per_prompt=3,
    generator=torch.Generator("cuda").manual_seed(0),
).audios
sf.write("result.wav", audio[0].T.float().cpu().numpy(), pipe.vae.sampling_rate)
